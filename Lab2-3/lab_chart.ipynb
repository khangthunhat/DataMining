# %%
import pandas as pd
import pygwalker as pyg

# %%
data = pd.read_csv('./TotnghiepOK.csv')
data
# Out:
# /var/folders/f7/qm1l4pnj4zngs_4y69yv1g9c0000gn/T/ipykernel_8688/1384372239.py:1: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('./TotnghiepOK.csv')
#           SoBD  Toan   Van  Anh    Ly   Hoa  Sinh   Su   Dia  GDCD  KhoiA  \
# 0            1   3.0  3.75  3.0  0.00  0.00  0.00  3.0  6.50  8.25   0.00
# 1            2   8.8  7.50  9.0  0.00  0.00  0.00  6.0  9.00  8.25   0.00
# 2            3   6.0  5.50  4.0  5.75  5.50  5.00  0.0  0.00  0.00  17.25
# 3            4   3.4  5.75  2.6  0.00  0.00  0.00  3.5  4.75  7.25   0.00
# 4            5   3.8  6.75  3.0  0.00  0.00  0.00  3.5  6.25  8.00   0.00
# ...        ...   ...   ...  ...   ...   ...   ...  ...   ...   ...    ...
# 744391  744392   4.6  4.50  6.0  3.75  3.00  3.25  0.0  0.00  0.00  11.35
# 744392  744393   7.0  6.00  5.0  5.25  5.50  4.00  0.0  0.00  0.00  17.75
# 744393  744394   5.2  3.50  4.0  6.25  5.50  2.25  0.0  0.00  0.00  16.95
# ...
